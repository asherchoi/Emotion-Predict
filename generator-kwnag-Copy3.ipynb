# %% [markdown]
# model

# %%
import keras
#from cnnmodel import model
from keras.preprocessing.image import ImageDataGenerator, load_img
import numpy as np
import matplotlib.pylab as plt
import tensorflow as tf
import os, random, cv2
from keras.utils import to_categorical
# Out:
# /opt/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
def createFileList(myDir):
    format = ('.tiff','.jpg','.png','.PNG')
    fileList = []
    print(os.walk(myDir, topdown=False))
    for root, dirs, files in os.walk(myDir, topdown=False):
        
        for name in files:
            if name.endswith(format):
                fullName = os.path.join(root, name)
                fileList.append(fullName)
    return fileList

# %%
classes={0:'angry', 1:'fear', 2:'happy', 3:'neutral', 4:'sad', 5:'surprise'}




batch_size = 32
epochs = 60

train_x = [] #(10000,1,227,227) (1,227,227)에 대해 append
train_y = [] #(10000, 6) 


#train_dir에 적용
#e.g. case sad
#path 읽어 = [(1,227,227)만들기 |  파싱하여 label 얻기] 

#train_x.append(q)
'''
z = load_img(path = './data/train/sad/KA.SA2.34.tiff', grayscale=True, target_size=(227,227),
    interpolation='nearest')
q=np.asarray(z).astype('float32')
print(np.asarray([q]).shape)
q = np.asarray([q])
'''

fileList = []
fileList = createFileList('./data/train')



for x in fileList:
    z = load_img(path =x, grayscale=True, target_size=(227,227),
    interpolation='nearest')
    q=np.asarray(z).astype('float32')
    q = np.asarray([q])
    train_x.append(q)
    
    t = -1
    for y in classes.items():
        if y[1] in x:
            t = y[0]
        
    train_y.append(to_categorical(t, 6))

train_x = np.asarray(train_x)
train_y = np.asarray(train_y)
print(train_x.shape)   
print(train_y.shape)   

train_len = train_x.shape[0]
print(train_len)
# Out:
# <generator object walk at 0x7f7b590c6e08>
# (1992, 1, 227, 227)
# (1992, 6)
# 1992

# %%
#이상  train_x/ train_y 구성 끝

#val_x/ val_y 도 일단 똑같이 구성

val_x = []
val_y = []


fileList = createFileList('./data/valid')



for x in fileList:
    z = load_img(path =x, grayscale=True, target_size=(227,227),
    interpolation='nearest')
    q=np.asarray(z).astype('float32')
    q = np.asarray([q])
    val_x.append(q)
    
    t = -1
    for y in classes.items():
        if y[1] in x:
            t = y[0]
        
    val_y.append(to_categorical(t, 6))

val_x = np.asarray(val_x)
val_y = np.asarray(val_y)
print(val_x.shape)   
print(val_y.shape)   

val_len = train_x.shape[0]
# Out:
# <generator object walk at 0x7f7b590c6f68>
# (199, 1, 227, 227)
# (199, 6)

# %%
train_datagen = ImageDataGenerator(
    featurewise_center=True,
    featurewise_std_normalization=True,
    #rescale=1./255,
    rotation_range=10,
    shear_range=0.1,
    fill_mode = 'constant',
    cval = 0,
    horizontal_flip=True)

print(train_x.shape)
train_x_moveaxis = np.moveaxis(train_x, 1, 3)  
print(train_x_moveaxis.shape)
train_datagen.fit(train_x_moveaxis)

train_x_mean = train_datagen.mean
print(train_x_mean)
# Out:
# (1992, 1, 227, 227)
# (1992, 227, 227, 1)
# [[[118.80855]]]

# %%
print(val_x.shape)
# Out:
# (199, 1, 227, 227)

# %%
val_datagen = ImageDataGenerator(
    featurewise_center=True,
    featurewise_std_normalization=True,
    #rescale=1./255, 
)
val_x_moveaxis = np.moveaxis(val_x, 1, 3)  
val_datagen.fit(val_x_moveaxis)
#val_datagen.mean = x꺼 배끼끼
print(val_datagen.mean)
val_datagen.mean = train_x_mean
print(val_datagen.mean)
# Out:
# [[[118.370995]]]
# [[[118.80855]]]

# %%
test_x = []
test_y = []


fileList = createFileList('./data/test')



for x in fileList:
    z = load_img(path =x, grayscale=True, target_size=(227,227),
    interpolation='nearest')
    q=np.asarray(z).astype('float32')
    q = np.asarray([q])
    test_x.append(q)
    
    t = -1
    for y in classes.items():
        if y[1] in x:
            t = y[0]
        
    test_y.append(to_categorical(t, 6))

test_x = np.asarray(test_x)
test_y = np.asarray(test_y)
print(test_x.shape)   
print(test_y.shape)   

test_len = train_x.shape[0]


test_datagen = ImageDataGenerator(
    featurewise_center=True,
    featurewise_std_normalization=True,
    #rescale=1./255, 
)
test_x_moveaxis = np.moveaxis(test_x, 1, 3)  
test_datagen.fit(test_x_moveaxis)
#val_datagen.mean = x꺼 배끼끼
print(test_datagen.mean)
test_datagen.mean = train_x_mean
print(test_datagen.mean)

# %%
#sequential model definition
#model.compile
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Convolution2D, MaxPooling2D
from keras.optimizers import Adadelta
from keras.layers.normalization import BatchNormalization


def model_generate():
    img_rows, img_cols = 227, 227
    model = Sequential()
    model.add(Convolution2D(36, 11, 11, border_mode='valid',
                            input_shape=(img_rows, img_cols,1)))
    model.add(BatchNormalization())
    model.add(keras.layers.advanced_activations.PReLU(init='zero', weights=None))
    model.add(keras.layers.convolutional.ZeroPadding2D(padding=(2, 2), dim_ordering='tf'))
    model.add(MaxPooling2D(pool_size=(5, 5),strides=(2, 2)))
    model.add(keras.layers.convolutional.ZeroPadding2D(padding=(1, 1), dim_ordering='tf')) 
    
    model.add(Convolution2D(96, 5, 5))
    model.add(BatchNormalization())
    model.add(keras.layers.advanced_activations.PReLU(init='zero', weights=None))
    model.add(keras.layers.convolutional.ZeroPadding2D(padding=(1, 1), dim_ordering='tf')) 
    
    model.add(Convolution2D(144, 3, 3))
    model.add(BatchNormalization())
    model.add(keras.layers.advanced_activations.PReLU(init='zero', weights=None))
    model.add(keras.layers.convolutional.AveragePooling2D(pool_size=(3, 3),strides=(2, 2)))
     
    model.add(keras.layers.convolutional.ZeroPadding2D(padding=(1, 1), dim_ordering='tf'))
    model.add(Convolution2D(96, 3, 3))
    model.add(BatchNormalization())
    model.add(keras.layers.advanced_activations.PReLU(init='zero', weights=None))
    
    model.add(keras.layers.convolutional.ZeroPadding2D(padding=(1, 1), dim_ordering='tf'))
    model.add(Convolution2D(128, 3, 3))
    model.add(BatchNormalization())
    model.add(keras.layers.advanced_activations.PReLU(init='zero', weights=None))
     
    model.add(keras.layers.convolutional.ZeroPadding2D(padding=(1, 1), dim_ordering='tf'))
    model.add(keras.layers.convolutional.AveragePooling2D(pool_size=(3, 3),strides=(2, 2)))
     
    model.add(Flatten())
    model.add(Dense(1024))
    model.add(BatchNormalization())
    model.add(keras.layers.advanced_activations.PReLU(init='zero', weights=None))
    model.add(Dropout(0.2))
    
    model.add(Dense(1024))
    model.add(BatchNormalization())
    model.add(keras.layers.advanced_activations.PReLU(init='zero', weights=None))
    model.add(Dropout(0.2))
     
      
    model.add(Dense(6))
    model.add(BatchNormalization())
      
    model.add(Activation('softmax'))

    ada = Adadelta(lr=0.1, rho=0.95, epsilon=1e-08)
    #model = multi_gpu_model(model, gpus=2)
    model.compile(loss='categorical_crossentropy',
                  optimizer=ada,
                  metrics=['accuracy'])
    model.summary()
    return model

model = model_generate()


filepath='model_8.hdf5'
checkpointer = keras.callbacks.ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=False, mode='auto')
# Out:
# /opt/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:14: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(36, (11, 11), input_shape=(227, 227,..., padding="valid")`
#
# /opt/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:16: UserWarning: Update your `PReLU` call to the Keras 2 API: `PReLU(weights=None, alpha_initializer="zero")`
#   app.launch_new_instance()
# /opt/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:17: UserWarning: Update your `ZeroPadding2D` call to the Keras 2 API: `ZeroPadding2D(padding=(2, 2), data_format="channels_last")`
# /opt/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:19: UserWarning: Update your `ZeroPadding2D` call to the Keras 2 API: `ZeroPadding2D(padding=(1, 1), data_format="channels_last")`
# /opt/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:21: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(96, (5, 5))`
# /opt/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:23: UserWarning: Update your `PReLU` call to the Keras 2 API: `PReLU(weights=None, alpha_initializer="zero")`
# /opt/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:24: UserWarning: Update your `ZeroPadding2D` call to the Keras 2 API: `ZeroPadding2D(padding=(1, 1), data_format="channels_last")`
# /opt/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:26: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(144, (3, 3))`
# /opt/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:28: UserWarning: Update your `PReLU` call to the Keras 2 API: `PReLU(weights=None, alpha_initializer="zero")`
# /opt/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:31: UserWarning: Update your `ZeroPadding2D` call to the Keras 2 API: `ZeroPadding2D(padding=(1, 1), data_format="channels_last")`
# /opt/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:32: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(96, (3, 3))`
# /opt/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:34: UserWarning: Update your `PReLU` call to the Keras 2 API: `PReLU(weights=None, alpha_initializer="zero")`
# /opt/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:36: UserWarning: Update your `ZeroPadding2D` call to the Keras 2 API: `ZeroPadding2D(padding=(1, 1), data_format="channels_last")`
# /opt/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:37: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (3, 3))`
# /opt/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:39: UserWarning: Update your `PReLU` call to the Keras 2 API: `PReLU(weights=None, alpha_initializer="zero")`
# /opt/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:41: UserWarning: Update your `ZeroPadding2D` call to the Keras 2 API: `ZeroPadding2D(padding=(1, 1), data_format="channels_last")`
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_6 (Conv2D)            (None, 217, 217, 36)      4392
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 217, 217, 36)      144
# _________________________________________________________________
# p_re_lu_8 (PReLU)            (None, 217, 217, 36)      1695204
# _________________________________________________________________
# zero_padding2d_7 (ZeroPaddin (None, 221, 221, 36)      0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 109, 109, 36)      0
# _________________________________________________________________
# zero_padding2d_8 (ZeroPaddin (None, 111, 111, 36)      0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 107, 107, 96)      86496
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 107, 107, 96)      384
# _________________________________________________________________
# p_re_lu_9 (PReLU)            (None, 107, 107, 96)      1099104
# _________________________________________________________________
# zero_padding2d_9 (ZeroPaddin (None, 109, 109, 96)      0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 107, 107, 144)     124560
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 107, 107, 144)     576
# _________________________________________________________________
# p_re_lu_10 (PReLU)           (None, 107, 107, 144)     1648656
# _________________________________________________________________
# average_pooling2d_3 (Average (None, 53, 53, 144)       0
# _________________________________________________________________
# zero_padding2d_10 (ZeroPaddi (None, 55, 55, 144)       0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 53, 53, 96)        124512
# _________________________________________________________________
# batch_normalization_12 (Batc (None, 53, 53, 96)        384
# _________________________________________________________________
# p_re_lu_11 (PReLU)           (None, 53, 53, 96)        269664
# _________________________________________________________________
# zero_padding2d_11 (ZeroPaddi (None, 55, 55, 96)        0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 53, 53, 128)       110720
# _________________________________________________________________
# batch_normalization_13 (Batc (None, 53, 53, 128)       512
# _________________________________________________________________
# p_re_lu_12 (PReLU)           (None, 53, 53, 128)       359552
# _________________________________________________________________
# zero_padding2d_12 (ZeroPaddi (None, 55, 55, 128)       0
# _________________________________________________________________
# average_pooling2d_4 (Average (None, 27, 27, 128)       0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 93312)             0
# _________________________________________________________________
# dense_4 (Dense)              (None, 1024)              95552512
# _________________________________________________________________
# batch_normalization_14 (Batc (None, 1024)              4096
# _________________________________________________________________
# p_re_lu_13 (PReLU)           (None, 1024)              1024
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_5 (Dense)              (None, 1024)              1049600
# _________________________________________________________________
# batch_normalization_15 (Batc (None, 1024)              4096
# _________________________________________________________________
# p_re_lu_14 (PReLU)           (None, 1024)              1024
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_6 (Dense)              (None, 6)                 6150
# _________________________________________________________________
# batch_normalization_16 (Batc (None, 6)                 24
# _________________________________________________________________
# activation_2 (Activation)    (None, 6)                 0
# =================================================================
# Total params: 102,143,386
# Trainable params: 102,138,278
# Non-trainable params: 5,108
# _________________________________________________________________
# /opt/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:47: UserWarning: Update your `PReLU` call to the Keras 2 API: `PReLU(weights=None, alpha_initializer="zero")`
# /opt/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:52: UserWarning: Update your `PReLU` call to the Keras 2 API: `PReLU(weights=None, alpha_initializer="zero")`

# %%
model.fit_generator(train_datagen.flow(train_x_moveaxis, train_y, batch_size =batch_size),
                    #steps_per_epoch = train_len/batch_size*12,
                    steps_per_epoch = train_len/batch_size*4,
                    epochs = epochs,
                    validation_data = val_datagen.flow(val_x_moveaxis,val_y,batch_size = batch_size),
                    callbacks = [checkpointer])

#l = train_datagen.flow(train_x_moveaxis, train_y, batch_size =batch_size)

#next(l)[0].shape
# Out:
# Epoch 1/60
# 249/249 [==============================] - 73s 294ms/step - loss: 0.9229 - acc: 0.7411 - val_loss: 0.5711 - val_acc: 0.9095
#
# Epoch 00001: saving model to model_8.hdf5
# Epoch 2/60
# 249/249 [==============================] - 72s 290ms/step - loss: 0.6753 - acc: 0.8753 - val_loss: 0.5461 - val_acc: 0.9397
#
# Epoch 00002: saving model to model_8.hdf5
# Epoch 3/60
# 249/249 [==============================] - 73s 291ms/step - loss: 0.5813 - acc: 0.9241 - val_loss: 0.4513 - val_acc: 0.9799
#
# Epoch 00003: saving model to model_8.hdf5
# Epoch 4/60
# 249/249 [==============================] - 72s 291ms/step - loss: 0.5200 - acc: 0.9544 - val_loss: 0.4815 - val_acc: 0.9950
#
# Epoch 00004: saving model to model_8.hdf5
# Epoch 5/60
# 249/249 [==============================] - 72s 290ms/step - loss: 0.4897 - acc: 0.9629 - val_loss: 0.4256 - val_acc: 0.9849
#
# Epoch 00005: saving model to model_8.hdf5
# Epoch 6/60
# 249/249 [==============================] - 72s 291ms/step - loss: 0.4509 - acc: 0.9747 - val_loss: 0.3886 - val_acc: 1.0000
#
# Epoch 00006: saving model to model_8.hdf5
# Epoch 7/60
# 249/249 [==============================] - 72s 291ms/step - loss: 0.4324 - acc: 0.9801 - val_loss: 0.3463 - val_acc: 1.0000
#
# Epoch 00007: saving model to model_8.hdf5
# Epoch 8/60
# 249/249 [==============================] - 72s 291ms/step - loss: 0.4127 - acc: 0.9832 - val_loss: 0.3610 - val_acc: 1.0000
#
# Epoch 00008: saving model to model_8.hdf5
# Epoch 9/60
# 249/249 [==============================] - 72s 290ms/step - loss: 0.3931 - acc: 0.9880 - val_loss: 0.3248 - val_acc: 1.0000
#
# Epoch 00009: saving model to model_8.hdf5
# Epoch 10/60
# 249/249 [==============================] - 73s 291ms/step - loss: 0.3710 - acc: 0.9898 - val_loss: 0.3004 - val_acc: 1.0000
#
# Epoch 00010: saving model to model_8.hdf5
# Epoch 11/60
# 249/249 [==============================] - 72s 290ms/step - loss: 0.3612 - acc: 0.9888 - val_loss: 0.3547 - val_acc: 1.0000
#
# Epoch 00011: saving model to model_8.hdf5
# Epoch 12/60
# 249/249 [==============================] - 72s 291ms/step - loss: 0.3491 - acc: 0.9920 - val_loss: 0.3116 - val_acc: 1.0000
#
# Epoch 00012: saving model to model_8.hdf5
# Epoch 13/60
# 249/249 [==============================] - 72s 291ms/step - loss: 0.3369 - acc: 0.9915 - val_loss: 0.2942 - val_acc: 1.0000
#
# Epoch 00013: saving model to model_8.hdf5
# Epoch 14/60
# 249/249 [==============================] - 72s 290ms/step - loss: 0.3353 - acc: 0.9914 - val_loss: 0.2774 - val_acc: 1.0000
#
# Epoch 00014: saving model to model_8.hdf5
# Epoch 15/60
# 249/249 [==============================] - 72s 291ms/step - loss: 0.3169 - acc: 0.9955 - val_loss: 0.2608 - val_acc: 1.0000
#
# Epoch 00015: saving model to model_8.hdf5
# Epoch 16/60
# 249/249 [==============================] - 72s 290ms/step - loss: 0.3059 - acc: 0.9934 - val_loss: 0.2524 - val_acc: 1.0000
#
# Epoch 00016: saving model to model_8.hdf5
# Epoch 17/60
# 249/249 [==============================] - 72s 291ms/step - loss: 0.2950 - acc: 0.9952 - val_loss: 0.2353 - val_acc: 1.0000
#
# Epoch 00017: saving model to model_8.hdf5
# Epoch 18/60
# 249/249 [==============================] - 72s 291ms/step - loss: 0.2856 - acc: 0.9940 - val_loss: 0.2440 - val_acc: 1.0000
#
# Epoch 00018: saving model to model_8.hdf5
# Epoch 19/60
# 249/249 [==============================] - 72s 291ms/step - loss: 0.2843 - acc: 0.9924 - val_loss: 0.2331 - val_acc: 1.0000
#
# Epoch 00019: saving model to model_8.hdf5
# Epoch 20/60
# 249/249 [==============================] - 72s 291ms/step - loss: 0.2756 - acc: 0.9957 - val_loss: 0.2228 - val_acc: 1.0000
#
# Epoch 00020: saving model to model_8.hdf5
# Epoch 21/60
# 249/249 [==============================] - 72s 291ms/step - loss: 0.2614 - acc: 0.9965 - val_loss: 0.2349 - val_acc: 1.0000
#
# Epoch 00021: saving model to model_8.hdf5
# Epoch 22/60
# 249/249 [==============================] - 72s 291ms/step - loss: 0.2585 - acc: 0.9954 - val_loss: 0.2158 - val_acc: 1.0000
#
# Epoch 00022: saving model to model_8.hdf5
# Epoch 23/60
# 249/249 [==============================] - 72s 291ms/step - loss: 0.2515 - acc: 0.9960 - val_loss: 0.2052 - val_acc: 1.0000
#
# Epoch 00023: saving model to model_8.hdf5
# Epoch 24/60
# 249/249 [==============================] - 72s 291ms/step - loss: 0.2397 - acc: 0.9980 - val_loss: 0.1931 - val_acc: 1.0000
#
# Epoch 00024: saving model to model_8.hdf5
# Epoch 25/60
# 249/249 [==============================] - 72s 290ms/step - loss: 0.2354 - acc: 0.9974 - val_loss: 0.1964 - val_acc: 1.0000
#
# Epoch 00025: saving model to model_8.hdf5
# Epoch 26/60
# 249/249 [==============================] - 72s 290ms/step - loss: 0.2303 - acc: 0.9972 - val_loss: 0.1823 - val_acc: 1.0000
#
# Epoch 00026: saving model to model_8.hdf5
# Epoch 27/60
# 249/249 [==============================] - 72s 290ms/step - loss: 0.2266 - acc: 0.9967 - val_loss: 0.1964 - val_acc: 1.0000
#
# Epoch 00027: saving model to model_8.hdf5
# Epoch 28/60
# 249/249 [==============================] - 73s 291ms/step - loss: 0.2186 - acc: 0.9982 - val_loss: 0.1818 - val_acc: 1.0000
#
# Epoch 00028: saving model to model_8.hdf5
# Epoch 29/60
# 249/249 [==============================] - 72s 290ms/step - loss: 0.2107 - acc: 0.9974 - val_loss: 0.1790 - val_acc: 1.0000
#
# Epoch 00029: saving model to model_8.hdf5
# Epoch 30/60
# 249/249 [==============================] - 72s 291ms/step - loss: 0.2082 - acc: 0.9965 - val_loss: 0.1774 - val_acc: 1.0000
#
# Epoch 00030: saving model to model_8.hdf5
# Epoch 31/60
# 249/249 [==============================] - 72s 290ms/step - loss: 0.2050 - acc: 0.9956 - val_loss: 0.1665 - val_acc: 1.0000
#
# Epoch 00031: saving model to model_8.hdf5
# Epoch 32/60
# 249/249 [==============================] - 73s 291ms/step - loss: 0.1979 - acc: 0.9979 - val_loss: 0.1589 - val_acc: 1.0000
#
# Epoch 00032: saving model to model_8.hdf5
# Epoch 33/60
# 249/249 [==============================] - 72s 291ms/step - loss: 0.1959 - acc: 0.9982 - val_loss: 0.1528 - val_acc: 1.0000
#
# Epoch 00033: saving model to model_8.hdf5
# Epoch 34/60
# 249/249 [==============================] - 72s 290ms/step - loss: 0.1946 - acc: 0.9974 - val_loss: 0.1455 - val_acc: 1.0000
#
# Epoch 00034: saving model to model_8.hdf5
# Epoch 35/60
# 249/249 [==============================] - 72s 291ms/step - loss: 0.1837 - acc: 0.9976 - val_loss: 0.1436 - val_acc: 1.0000
#
# Epoch 00035: saving model to model_8.hdf5
# Epoch 36/60
# 249/249 [==============================] - 72s 291ms/step - loss: 0.1839 - acc: 0.9969 - val_loss: 0.1435 - val_acc: 1.0000
#
# Epoch 00036: saving model to model_8.hdf5
# Epoch 37/60
# 249/249 [==============================] - 72s 290ms/step - loss: 0.1767 - acc: 0.9986 - val_loss: 0.1368 - val_acc: 1.0000
#
# Epoch 00037: saving model to model_8.hdf5
# Epoch 38/60
# 249/249 [==============================] - 72s 291ms/step - loss: 0.1762 - acc: 0.9972 - val_loss: 0.1304 - val_acc: 1.0000
#
# Epoch 00038: saving model to model_8.hdf5
# Epoch 39/60
# 249/249 [==============================] - 72s 290ms/step - loss: 0.1683 - acc: 0.9980 - val_loss: 0.1359 - val_acc: 1.0000
#
# Epoch 00039: saving model to model_8.hdf5
# Epoch 40/60
# 249/249 [==============================] - 73s 291ms/step - loss: 0.1621 - acc: 0.9976 - val_loss: 0.1245 - val_acc: 1.0000
#
# Epoch 00040: saving model to model_8.hdf5
# Epoch 41/60
# 249/249 [==============================] - 72s 291ms/step - loss: 0.1603 - acc: 0.9962 - val_loss: 0.1204 - val_acc: 1.0000
#
# Epoch 00041: saving model to model_8.hdf5
# Epoch 42/60
# 249/249 [==============================] - 72s 291ms/step - loss: 0.1613 - acc: 0.9971 - val_loss: 0.1131 - val_acc: 1.0000
#
# Epoch 00042: saving model to model_8.hdf5
# Epoch 43/60
# 249/249 [==============================] - 72s 290ms/step - loss: 0.1555 - acc: 0.9964 - val_loss: 0.1172 - val_acc: 1.0000
#
# Epoch 00043: saving model to model_8.hdf5
# Epoch 44/60
# 249/249 [==============================] - 72s 291ms/step - loss: 0.1500 - acc: 0.9989 - val_loss: 0.1143 - val_acc: 1.0000
#
# Epoch 00044: saving model to model_8.hdf5
# Epoch 45/60
# 249/249 [==============================] - 72s 291ms/step - loss: 0.1471 - acc: 0.9990 - val_loss: 0.1122 - val_acc: 1.0000
#
# Epoch 00045: saving model to model_8.hdf5
# Epoch 46/60
# 249/249 [==============================] - 72s 291ms/step - loss: 0.1474 - acc: 0.9977 - val_loss: 0.1258 - val_acc: 1.0000
#
# Epoch 00046: saving model to model_8.hdf5
# Epoch 47/60
# 249/249 [==============================] - 73s 291ms/step - loss: 0.1441 - acc: 0.9969 - val_loss: 0.1079 - val_acc: 1.0000
#
# Epoch 00047: saving model to model_8.hdf5
# Epoch 48/60
# 249/249 [==============================] - 72s 290ms/step - loss: 0.1390 - acc: 0.9985 - val_loss: 0.1049 - val_acc: 1.0000
#
# Epoch 00048: saving model to model_8.hdf5
# Epoch 49/60
# 249/249 [==============================] - 72s 291ms/step - loss: 0.1316 - acc: 0.9995 - val_loss: 0.1161 - val_acc: 1.0000
#
# Epoch 00049: saving model to model_8.hdf5
# Epoch 50/60
# 249/249 [==============================] - 72s 291ms/step - loss: 0.1327 - acc: 0.9979 - val_loss: 0.1160 - val_acc: 1.0000
#
# Epoch 00050: saving model to model_8.hdf5
# Epoch 51/60
# 249/249 [==============================] - 72s 291ms/step - loss: 0.1306 - acc: 0.9989 - val_loss: 0.0947 - val_acc: 1.0000
#
# Epoch 00051: saving model to model_8.hdf5
# Epoch 52/60
# 249/249 [==============================] - 72s 290ms/step - loss: 0.1290 - acc: 0.9982 - val_loss: 0.1033 - val_acc: 1.0000
#
# Epoch 00052: saving model to model_8.hdf5
# Epoch 53/60
# 249/249 [==============================] - 72s 291ms/step - loss: 0.1211 - acc: 0.9989 - val_loss: 0.0949 - val_acc: 1.0000
#
# Epoch 00053: saving model to model_8.hdf5
# Epoch 54/60
# 249/249 [==============================] - 72s 290ms/step - loss: 0.1289 - acc: 0.9984 - val_loss: 0.0917 - val_acc: 1.0000
#
# Epoch 00054: saving model to model_8.hdf5
# Epoch 55/60
# 249/249 [==============================] - 72s 291ms/step - loss: 0.1243 - acc: 0.9979 - val_loss: 0.0904 - val_acc: 1.0000
#
# Epoch 00055: saving model to model_8.hdf5
# Epoch 56/60
# 249/249 [==============================] - 72s 290ms/step - loss: 0.1206 - acc: 0.9980 - val_loss: 0.0909 - val_acc: 1.0000
#
# Epoch 00056: saving model to model_8.hdf5
# Epoch 57/60
# 249/249 [==============================] - 72s 290ms/step - loss: 0.1154 - acc: 0.9995 - val_loss: 0.0920 - val_acc: 1.0000
#
# Epoch 00057: saving model to model_8.hdf5
# Epoch 58/60
# 249/249 [==============================] - 72s 291ms/step - loss: 0.1124 - acc: 0.9985 - val_loss: 0.0849 - val_acc: 1.0000
#
# Epoch 00058: saving model to model_8.hdf5
# Epoch 59/60
# 249/249 [==============================] - 72s 291ms/step - loss: 0.1124 - acc: 0.9984 - val_loss: 0.0797 - val_acc: 1.0000
#
# Epoch 00059: saving model to model_8.hdf5
# Epoch 60/60
# 249/249 [==============================] - 72s 291ms/step - loss: 0.1116 - acc: 0.9986 - val_loss: 0.0782 - val_acc: 1.0000
#
# Epoch 00060: saving model to model_8.hdf5

# %%
#classes={0:'angry', 1:'fear', 2:'happy', 3:'neutral', 4:'sad', 5:'surprise'}
#vd = val_datagen.flow(val_x_moveaxis,val_y,batch_size = 1)
#sample = vd.next()
#sample_x,sample_y = sample
#print(sam)
from keras.models import load_model

model = load_model(filepath)
"""
test_datagen = ImageDataGenerator(
    featurewise_center=True,
    featurewise_std_normalization=True,
    #rescale=1./255, 
)
#print("0hi")
#print(test_datagen.mean)
test_datagen.fit(val_x_moveaxis[:10])
#print(test_datagen.mean)
test_datagen.mean = val_datagen.mean
#print(test_datagen.mean)
"""


e = model.predict_generator(test_datagen.flow(test_x_moveaxis,test_y,batch_size = 1,shuffle= False))
print(val_datagen.mean)
print([np.argmax(pre) for pre in e])
#print(val_x_moveaxis[0])
#print(val_y)
#print(e)
print([np.argmax(x) for x in test_y])

# %%
correct = 0
for x,y in zip(e,test_y):
    if np.argmax(x) == np.argmax(y):
        correct+=1
    else: continue
        
print(float(correct)/len(test_y)*100)

# %% [markdown]
# A total data # * steps for epochs / batchsize  ==  172
# Therefore, 172 * 32(batchsize) == A total data #

# %%
valid_x = [] #(10000,1,227,227) (1,227,227)에 대해 append
valid_y = [] #(10000, 6) 


fileList = []
fileList = createFileList('./data/valid')



for x in fileList:
    z = load_img(path =x, grayscale=True, target_size=(227,227),
    interpolation='nearest')
    q=np.asarray(z).astype('float32')
    q = np.asarray([q])
    valid_x.append(q)
    
    t = -1
    for y in classes.items():
        if y[1] in x:
            t = y[0]
        
    valid_y.append(to_categorical(t, 6))

    
valid_x = np.asarray(valid_x)
valid_y = np.asarray(valid_y)
print(valid_x.shape)   
print(valid_y.shape)   
valid_x_moveaxis = np.moveaxis(valid_x, 1, 3)  
valid_x_moveaxis.shape

# %%
valid_datagen = ImageDataGenerator(
    featurewise_center=True,
    featurewise_std_normalization=True,
    #rescale=1./255, 
)
#print("0hi")
#print(test_datagen.mean)
valid_datagen.fit(valid_x_moveaxis[:])
print(valid_datagen.mean)
valid_datagen.mean = [[[0]]]
print(valid_datagen.mean)



e1 = model.predict_generator(valid_datagen.flow(valid_x_moveaxis,valid_y,batch_size = 1,shuffle= False))
print(valid_datagen.mean)
print([np.argmax(pre) for pre in e1])
#print(val_x_moveaxis[0])
#print(val_y)
print(e1)
print([np.argmax(x) for x in valid_y])



correct = 0
for x,y in zip(e1,valid_y):
    if np.argmax(x) == np.argmax(y):
        correct+=1
    else: continue
        
print(float(correct)/len(valid_y)*100)
